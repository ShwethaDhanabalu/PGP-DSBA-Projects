# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         You have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Follow the steps below for preparation of the report.
#
# Before you start analysing the data, it is always a good practice to see the size of the data, its features and feature types. If the data set is big, it is not possible to print out all the records.
#     </font>
# ####  Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ## Load the necessary libraries. Import and load the dataset with a name ECom_Data .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 10

# %%
# Get the Data

ECom_Data=pd.read_csv("E-Commerce_Flipkart.csv")

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         We have read the data and stored the data in "ECom_Data" variable </font>

# %% [markdown]
# ## Q 1.	To get familiar with the data
# ## a)	Print out the first 10 and the last 10 records of the data. (2 marks)
# ## b)	How many rows and columns are present in the dataset? Use any two different methods to extract this information. (2 + 2 + 1 marks)
# ## c)	How many object data types are there? (1 mark)
# ## d)	Is there any Boolean data type? (1 mark)
# #### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# #### Ans 1 a)

# %% [markdown]
# First 10 records of the dataset

# %%
ECom_Data.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  c2d766ca982eca8304150849735ffef9  North  31-12-2021               3/1/2022
# 1  7f7036a6d550aaa89d34c77bd39a5e48  East   31-12-2021               3/1/2022
# 2  f449ec65dcbc041b6ae5e6a32717d01b  East   31-12-2021               3/1/2022
# 3  0973b37acd0c664e3de26e97e5571454   West  31-12-2021               3/1/2022
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7   West  31-12-2021               3/1/2022
# 5  ce5a6818f7707e2cb61fdcdbba61f5ad  East   25-12-2021             28-12-2021
# 6  8542703ca9e6ebdf6d742638dfb1f2ca  East   25-12-2021             28-12-2021
# 7  29c8d290caa451f97b1c32df64477a2c  North  25-12-2021             28-12-2021
# 8  4044c0ac52c1ee4b28777417651faf42  East   25-12-2021             28-12-2021
# 9  e54bc0a7c3429da2ebef0b30331fe3d2  East   25-12-2021             28-12-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %% [markdown]
# Last 10 records of the dataset

# %%
ECom_Data.tail(10)
# Out:
#                       Customer_uniq_id Region Order_Date  \
# 8917  4db03bc4ccbe216cf151b2f2b904ba3f  East   1/12/2020
# 8918  4d4d6aeb13fa253499d0dd45a5abd87e   West  1/12/2020
# 8919  ea19e7ef703293d3f6c799ca9db4642d   West  1/12/2020
# 8920  19a53a958992fb575acffb5d41e7ef9e  East   1/12/2020
# 8921  09abab80c8dfdc6f268e0a6f05a0be11  North  1/12/2020
# 8922  90d30478255e23621e8929ed15c2f6e4  South  1/12/2020
# 8923  20a73e3f41490a73ceeba5f17658db8f   West  1/12/2020
# 8924  5c1554cd45f9d538c2c6947dbdd59c75  East   1/12/2020
# 8925  6b737a4deca1ed0e56c179e66036e994   West  1/12/2020
# 8926  a5235ac28d3d5487f54025f9d6b57433  North  1/12/2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8917              4/12/2020      4/12/2020
# 8918              4/12/2020      4/12/2020
# 8919              4/12/2020      4/12/2020
# 8920              4/12/2020      4/12/2020
# 8921              4/12/2020      4/12/2020
# 8922              4/12/2020      4/12/2020
# ...

# %% [markdown]
# #### Ans 1 b)

# %% [markdown]
# Method 1: using shape method

# %%
print('Number of rows present in the dataset:',ECom_Data.shape[0])
print('Number of columns present in the dataset:',ECom_Data.shape[1])
# Out:
# Number of rows present in the dataset: 8927
# Number of columns present in the dataset: 17

# %% [markdown]
# Method 2: using info() method

# %%
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8927 entries, 0 to 8926
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8927 non-null   object
#  1   Region                      8927 non-null   object
#  2   Order_Date                  8927 non-null   object
#  3   Expected_Delivery_Date      8927 non-null   object
#  4   Delivered_Date              8927 non-null   object
#  5   product_name                8927 non-null   object
#  6   product_main_category       8927 non-null   object
#  7   product_subcategory         8927 non-null   object
#  8   product_category_filter     8927 non-null   object
#  9   product_category_subfilter  8927 non-null   object
#  10  product_unique ID           8927 non-null   object
#  11  retail_price                8927 non-null   int64
#  12  discounted_price            8927 non-null   int64
# ...

# %% [markdown]
# Number of rows - 8927<br>
# Number of column - 17

# %% [markdown]
# #### Ans  1 c)

# %%
print('Number of object data types in the data set is',(ECom_Data.dtypes==object).sum())
# Out:
# Number of object data types in the data set is 14

# %% [markdown]
# ### Ans 1 d)

# %%
print('Number of bool data types in the data set is',(ECom_Data.dtypes==bool).sum())
# Out:
# Number of bool data types in the data set is 0

# %% [markdown]
# There is no boolean data type

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#  Once you are familiar with the data, you may decide that not all features are of use to you and you may want to delete the non-informative features (columns)</font>

# %% [markdown]
# ## Q 2.	Eliminating the non-informative columns.
# ## a)	Drop the columns product_specifications and description. (2 marks)
# ## b)	Which method or function is used to permanently delete the columns mentioned in part (b)? Write the code explicitly (2 marks)
# ### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ### Ans 2 a)

# %%
ECom_Data.drop(['product_specifications','description'],axis=1)
ECom_Data
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     c2d766ca982eca8304150849735ffef9  North  31-12-2021
# 1     7f7036a6d550aaa89d34c77bd39a5e48  East   31-12-2021
# 2     f449ec65dcbc041b6ae5e6a32717d01b  East   31-12-2021
# 3     0973b37acd0c664e3de26e97e5571454   West  31-12-2021
# 4     bc940ea42ee6bef5ac7cea3fb5cfbee7   West  31-12-2021
# ...                                ...    ...         ...
# 8922  90d30478255e23621e8929ed15c2f6e4  South   1/12/2020
# 8923  20a73e3f41490a73ceeba5f17658db8f   West   1/12/2020
# 8924  5c1554cd45f9d538c2c6947dbdd59c75  East    1/12/2020
# 8925  6b737a4deca1ed0e56c179e66036e994   West   1/12/2020
# 8926  a5235ac28d3d5487f54025f9d6b57433  North   1/12/2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                  3/1/2022       2/1/2022
# 1                  3/1/2022       2/1/2022
# 2                  3/1/2022       2/1/2022
# 3                  3/1/2022       2/1/2022
# 4                  3/1/2022       2/1/2022
# ...

# %% [markdown]
# ### Ans 2 b)

# %% [markdown]
# Method inplace() is used to permanently delete the columns from the dataset

# %%
ECom_Data.drop(['product_specifications','description'],axis=1,inplace=True)
ECom_Data
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     c2d766ca982eca8304150849735ffef9  North  31-12-2021
# 1     7f7036a6d550aaa89d34c77bd39a5e48  East   31-12-2021
# 2     f449ec65dcbc041b6ae5e6a32717d01b  East   31-12-2021
# 3     0973b37acd0c664e3de26e97e5571454   West  31-12-2021
# 4     bc940ea42ee6bef5ac7cea3fb5cfbee7   West  31-12-2021
# ...                                ...    ...         ...
# 8922  90d30478255e23621e8929ed15c2f6e4  South   1/12/2020
# 8923  20a73e3f41490a73ceeba5f17658db8f   West   1/12/2020
# 8924  5c1554cd45f9d538c2c6947dbdd59c75  East    1/12/2020
# 8925  6b737a4deca1ed0e56c179e66036e994   West   1/12/2020
# 8926  a5235ac28d3d5487f54025f9d6b57433  North   1/12/2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                  3/1/2022       2/1/2022
# 1                  3/1/2022       2/1/2022
# 2                  3/1/2022       2/1/2022
# 3                  3/1/2022       2/1/2022
# 4                  3/1/2022       2/1/2022
# ...

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         The next steps in this project involves summarization of data at various levels and visualization. Such apparently simple steps are very useful to get an overall sense of the data.
#     </font>

# %% [markdown]
# ## Q 3. Here we summarize the data at brand level.
# ## a) How many unique Brands are there. (1 mark)
# ## b) Note that each brand contains multiple products. Show the average rating of the products within each Brand (2 marks)

# %% [markdown]
# ### Ans 3 a)

# %%
print('Count of unique brands in the dataset:',ECom_Data['Brand'].nunique())
# Out:
# Count of unique brands in the dataset: 2580

# %% [markdown]
# ### Ans 3 b)

# %%
pd.DataFrame(data=ECom_Data.groupby('Brand')['product_rating'].mean())
# Out:
#               product_rating
# Brand
# 1OAK                1.500000
# 3A AUTOCARE         3.268293
# 3D Mat              3.000000
# 3kFactory           2.000000
# 4D                  3.600000
# ...                      ...
# youniqueshop        2.000000
# zDelhi.com          5.000000
# zaidis              4.000000
# zasmina             4.500000
#  Tarkan             5.000000
#
# [2580 rows x 1 columns]

# %% [markdown]
# ## Q 4. Next we study the main categories of the products.
#
# ## a) Create an appropriate plot to show the count of items ordered for each product_main_category. (5 marks).
#
# ### Hint: Create a bar chart titled "Product Category type" where product names are on x-axis and counts are on y-axis.
#
# ### Note: Both axis labels, i.e. the names of the product categories and counts must be clearly legible.
#
# ## b) From the plot identify for which two product_main_category(s) the maximum and the minimum orders were placed. (2 marks)
#
# ## c) Write code to print out the top 5 product_main_category(s)  in descending order? (2 marks

# %% [markdown]
# ### Ans 4 a)

# %%
plt.figure(figsize=(20,5))
plt.title('Product Category type')
plt.xticks(rotation=90)
plt.yticks(range(0,3200,200))
sns.countplot(x='product_main_category',data=ECom_Data)
plt.xlabel('Product Category')
plt.ylabel('Counts');

# %% [markdown]
# ### Ans 4 b)

# %% [markdown]
# Maximum orders were placed in - Clothing, Mobiles & Accessories<br>
# Minimum orders were place in - Food & Nutrition, Wearable Smart Devices

# %% [markdown]
# ### Ans 4 c)

# %%
E_Com2=ECom_Data.groupby('product_main_category')['product_main_category'].count()
E_Com2.sort_values(ascending=False).head(5)
# Out:
# product_main_category
# Clothing                       2952
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
# Name: product_main_category, dtype: int64

# %% [markdown]
# Top 5 product categories are Clothing, Mobiles & Accessories, Automotive, Home Decor & Festive Needs, Computers

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business.
#     The E-Commerce company has the following rule for computing their own revenue, which depends on how much each retailer can sell. </font>
#
# ####     The company charges each retailer (Brand)
# ####  (i)	25% on the final price (discounted price) of total orders if the number of orders placed is greater than 600
# ####  (ii) 15% on the final price (discounted price) of total orders if the number of orders placed is greater than 350 but less than or equal to 600
# ####  (iii) 10% on the final price (discounted price) of total orders if the number of orders placed is greater than 100 but less than or equal to 350
# ####  (iv) Otherwise, 5% on the final price (discounted price) of total orders
#
#    </font>

# %% [markdown]
# ## Q 5. Find the net revenue generated by the E-Commerce company over all orders placed. (6 marks)

# %% [markdown]
# ### Ans 5

# %%
def revenue(discount_price):
    if (discount_price>600):
        val=0.25
    elif (discount_price>350 and discount_price<=600):
        val=0.15
    elif (discount_price>100 and discount_price<=350):
        val=0.10
    else:
        val=0.05
    return val*discount_price

# %%
ECom_Data['new_revenue'] =ECom_Data['discounted_price'].apply(revenue)
print('Net Revenue generated by the company is',ECom_Data['new_revenue'].sum())
# Out:
# Net Revenue generated by the company is 2242221.75

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Now you need to find the revenue for each retailer (Brand)
#     </font>

# %% [markdown]
# ## Q6.Calculate the BrandRevenue for each brand and list the top 14 brands having maximum revenue in descending order (5 marks)
# #### Hint: Brand revenue is different from the E-Commerce company revenue.

# %% [markdown]
# ### Ans 6

# %%
ECom_Brand_rev=ECom_Data.groupby('Brand')['new_revenue'].sum()
pd.DataFrame(ECom_Brand_rev.sort_values(ascending=False).head(14))
# Out:
#               new_revenue
# Brand
# Allure Auto     166154.75
# GAGA             79130.00
# DailyObjects     60660.00
# Slim             60114.40
# Diviniti         47705.00
# ...                   ...
# Regular          26367.65
# Lal Haveli       24499.05
# FabHomeDecor     22646.00
# Netgear          21969.50
# NITGEN           21716.25
#
# [14 rows x 1 columns]

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
# Let us now investigate multiple features for each product to determine any pattern.
# </font>

# %% [markdown]
# ## Q 7. Compare prices for each product.
#
# ## a)	Draw boxplots of retail_price & discount_price. (2 marks)
#
# ## b)	 Are there any outliers? (Yes/No) (1mark)
#
# ## c)	Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis) (2 marks)

# %% [markdown]
# ### Ans 7 a)

# %% [markdown]
# Boxplot of retail_price

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x='retail_price',data=ECom_Data);
plt.xticks(range(0,120001,10000));

# %% [markdown]
# Boxplot of discount_price

# %%
plt.figure(figsize=(20,5))
sns.boxplot(x='discounted_price',data=ECom_Data);
plt.xticks(range(0,120001,5000));

# %% [markdown]
# ### Ans 7 b)

# %% [markdown]
# Yes, there are outlies for both retail_price and discounted_price

# %% [markdown]
# ### Ans 7 c)

# %%
sns.scatterplot(data=ECom_Data,x='retail_price',y='discounted_price');

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The next steps will enable to study brand-level information.
#     </font>

# %% [markdown]
# ## Q 8. Create a new dataframe to include the brand specific information as stated:
# ## i.	total number of orders placed per brand
# ## ii.	total retail_price per brand
# ## iii.	total discount_price per brand, and
# ## iv.	total BrandRevenue generated per brand.
#
# ## Also, draw a pairplot using these four features. (3 marks)

# %% [markdown]
# ### Ans 8

# %%
new_ECom = pd.DataFrame(columns=['Brand','Total_Count','Total_Retail_Price','Total_discount_price','Total_BrandRevenue'])
for i in ECom_Data['Brand'].unique():
    brand=i
    tot_count=ECom_Data['Brand'].value_counts()[i]
    ret_price=ECom_Data.groupby('Brand')['retail_price'].sum()[i]
    discount_price=ECom_Data.groupby('Brand')['discounted_price'].sum()[i]
    brand_revenue=ECom_Data.groupby('Brand')['new_revenue'].sum()[i]
    new_ECom = new_ECom.append({'Brand':brand,'Total_Count':tot_count,'Total_Retail_Price':ret_price,'Total_discount_price':discount_price,'Total_BrandRevenue':brand_revenue},ignore_index=True)

# %%
new_ECom
# Out:
#                 Brand Total_Count Total_Retail_Price Total_discount_price  \
# 0              Alisha           6               6094                 2362
# 1        FabHomeDecor           4             128628                90584
# 2                  AW           5               2995                 1635
# 3              Sicons           2                520                  466
# 4       dilli bazaaar           1                699                  349
# ...               ...         ...                ...                  ...
# 2575        Shoetopia           1                499                  399
# 2576            Beanz           1               1299                 1299
# 2577           Sinina           2               4980                 2490
# 2578  Aarushi Fashion           2               5400                 2650
# 2579   Ambika Lahenga           1              39992                24995
#
#       Total_BrandRevenue
# 0                 340.95
# 1               22646.00
# ...

# %%
sns.pairplot(data=new_ECom[['Total_Count','Total_Retail_Price','Total_discount_price','Total_BrandRevenue']]);

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The E-Commerce company operate in multiple regions. It is important to understand its performance in each region.
#     </font>

# %% [markdown]
# ## Q 9.Compare performance regionwise
#
# ## a)	Draw a lineplot for the monthly Revenue of ECom Company for each region separately.  (4 marks)
#
# ## b)	Identify the best and the worst performing months for each region. (2 marks)

# %% [markdown]
# ### Ans 9 a)

# %%
ECom_Data['Order_Month']=pd.to_datetime(ECom_Data['Order_Date'],dayfirst=True)
ECom_Data['Month']=ECom_Data['Order_Month'].dt.month

# %%
plt.figure(figsize=(20,7))
g=sns.lineplot(data = ECom_Data , x = 'Month', y='new_revenue', hue='Region',ci=False)
g.set_xticks(range(1,13,1))
plt.ylabel('Revenue');

# %% [markdown]
# ### Ans 9 b)

# %% [markdown]
# Region - North<br>
# Best performing month - August<br>
# Worst performing month - July<br>
#
# Region - East<br>
# Best performing month - August<br>
# Worst performing month - October<br>
#
# Region - West<br>
# Best performing month - March<br>
# Worst performing month - October<br>
#
# Region - South<br>
# Best performing month - March<br>
# Worst performing month - May<br>

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Congratulations! You have learnt how to approach a complex data and extract information out of it.
#     </font>
